# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('sample.png')
name = 'OpenCV Python Image'
plt.title(name)
plt.imshow(img)

# %%
horizontal_flip = cv2.flip(img,1)
name = 'OpenCV Python FLipped Horizontally'
plt.title(name)
plt.imshow(horizontal_flip)

# %%
vertical_flip = cv2.flip(img,0)
name = 'OpenCV Python flipped vertically'
plt.title(name)
plt.imshow(vertical_flip)

# %%
vertical_horizontal = cv2.flip(img, -1)
name = 'OpenCV Python flipped vertically and horizontally'
plt.title(name)
plt.imshow(vertical_horizontal)

# %%
import cv2
from matplotlib import pyplot as plt
import PIL as pillow
import numpy as np

# %%
high_contrast = cv2.imread('redearedslider.jpg')
plt.imshow(high_contrast)

# %%
low_contrast = cv2.bitwise_not(high_contrast)
plt.imshow(low_contrast)
cv2.imwrite('lowered_contrast.jpg',low_contrast)
# Out:
# True

# %%
from PIL import Image
from numpy import array
im_1 = Image.open('redearedslider.jpg')
arr_1 = array(im_1)
arr_1

im_2 = Image.open('lowered_contrast.jpg')
arr_2 = array(im_2)
arr_2
# Out:
# array([[[158, 133, 227],
#         [159, 134, 228],
#         [159, 134, 228],
#         ...,
#         [150, 140, 203],
#         [148, 138, 201],
#         [150, 140, 203]],
#
#        [[159, 134, 228],
#         [159, 134, 228],
#         [159, 134, 228],
#         ...,
#         [151, 141, 204],
#         [149, 139, 202],
#         [150, 140, 203]],
#
#        [[159, 134, 228],
#         [159, 134, 228],
#         [159, 134, 228],
#         ...,
#         [152, 142, 205],
#         [150, 140, 203],
#         [150, 140, 203]],
#
#        ...,
#
#        [[138, 114, 174],
#         [138, 114, 174],
#         [139, 115, 175],
#         ...,
#         [203, 217, 217],
#         [196, 211, 214],
#         [191, 209, 213]],
#
#        [[139, 115, 175],
#         [138, 114, 174],
#         [139, 115, 175],
#         ...,
#         [204, 220, 219],
#         [195, 213, 215],
#         [190, 208, 212]],
#
#        [[139, 115, 175],
#         [138, 114, 174],
#         [139, 115, 175],
#         ...,
#         [207, 223, 222],
#         [196, 214, 216],
#         [189, 208, 212]]], dtype=uint8)

# %%
import numpy
import matplotlib.pyplot as plt

# %%
image = cv2.imread('sample.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.title('Original')
plt.imshow(image_rgb)

# %%
gray_image = cv2.imread('sample.png', cv2.COLOR_BGR2GRAY)

cv2.imwrite('sample.png', gray_image)

plt.title('Gray-sample')
plt.imshow(gray_image)
